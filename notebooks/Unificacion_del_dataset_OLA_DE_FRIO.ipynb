# %% [markdown]
# # Importo los datasets desde Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Lectura de archivos

# %%
import pandas as pd

# Leer los archivos desde Google Drive
path = "/content/drive/MyDrive/Ola_de_frio/"

# Leer el archivo 2021
df_2021 = pd.read_csv(path + 'Río Grande, Tierra del Fu... 2021-01-01 to 2021-12-31.csv')

# %%
# Leemos los otros datasets
df_2022 = pd.read_csv(path + 'Río Grande, Tierra del Fu... 2022-01-01 to 2022-12-31.csv')
df_2023 = pd.read_csv(path + 'Río Grande, Tierra del Fu... 2023-01-01 to 2023-12-31.csv')
df_2024 = pd.read_csv(path + 'Rio Grande, Tierra Del Fu... 2024-01-01 to 2024-12-31.csv')

# %% [markdown]
# # Unificamos los cuatro datasets

# %%
# unimos los dataset ya que cada uno se encuentra separado
# Unir datasets
df_diario = pd.concat([df_2021,df_2022, df_2023, df_2024], ignore_index=True)
df_diario.head(5)
# Out:
#                                       name    datetime  tempmax  tempmin  \
# 0  Río Grande, Tierra del Fuego, Argentina  2021-01-01     19.2     10.0
# 1  Río Grande, Tierra del Fuego, Argentina  2021-01-02     19.7     10.0
# 2  Río Grande, Tierra del Fuego, Argentina  2021-01-03     16.1      5.0
# 3  Río Grande, Tierra del Fuego, Argentina  2021-01-04     13.1      5.0
# 4  Río Grande, Tierra del Fuego, Argentina  2021-01-05     18.0      6.2
#
#    temp  feelslikemax  feelslikemin  feelslike   dew  humidity  ...  \
# 0  14.2          19.2          10.0       14.2  11.7      85.7  ...
# 1  14.8          19.7          10.0       14.8   6.3      58.1  ...
# 2  10.6          16.1           1.3        9.0   4.2      65.4  ...
# 3   9.8          13.1           0.0        8.2   4.5      70.5  ...
# 4  13.0          18.0           3.0       12.1   6.4      65.3  ...
#
#    solarenergy  uvindex  severerisk              sunrise               sunset  \
# ...
